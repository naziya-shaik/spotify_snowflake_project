# %%
# !pip install spotipy
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from datetime import datetime

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="34cab104275a408d9e05b8c1bdfca0dd", client_secret="e0ec036488814f7e8909de6b1159e6ca")
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)
playlist_link = "https://open.spotify.com/playlist/11WFO4XKNScIEbZNAwhM9M?si=ZFuiUAf9TQSS7O3GqVEg3A"
playlist_URI = playlist_link.split("/")[-1].split('?')[0]
data = sp.playlist_tracks(playlist_URI)
data['items']
# Out:
# [{'added_at': '2020-11-15T16:50:01Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1vrw9bgarqfl3o7kgpb3el8ym'},
#    'href': 'https://api.spotify.com/v1/users/1vrw9bgarqfl3o7kgpb3el8ym',
#    'id': '1vrw9bgarqfl3o7kgpb3el8ym',
#    'type': 'user',
#    'uri': 'spotify:user:1vrw9bgarqfl3o7kgpb3el8ym'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FgHPfRprDaylrSRVf1UlN'},
#       'href': 'https://api.spotify.com/v1/artists/2FgHPfRprDaylrSRVf1UlN',
#       'id': '2FgHPfRprDaylrSRVf1UlN',
#       'name': 'Thaman S',
#       'type': 'artist',
#       'uri': 'spotify:artist:2FgHPfRprDaylrSRVf1UlN'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2020-11-15T16:50:01Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1vrw9bgarqfl3o7kgpb3el8ym'},
#   'href': 'https://api.spotify.com/v1/users/1vrw9bgarqfl3o7kgpb3el8ym',
#   'id': '1vrw9bgarqfl3o7kgpb3el8ym',
#   'type': 'user',
#   'uri': 'spotify:user:1vrw9bgarqfl3o7kgpb3el8ym'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FgHPfRprDaylrSRVf1UlN'},
#      'href': 'https://api.spotify.com/v1/artists/2FgHPfRprDaylrSRVf1UlN',
#      'id': '2FgHPfRprDaylrSRVf1UlN',
#      'name': 'Thaman S',
#      'type': 'artist',
#      'uri': 'spotify:artist:2FgHPfRprDaylrSRVf1UlN'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
# ...

# %%
data['items'][0]['track']['type']
# Out:
# 'track'

# %%
len(data['items'])
# Out:
# 100

# %%
data['items'][0]['track']['album']
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FgHPfRprDaylrSRVf1UlN'},
#    'href': 'https://api.spotify.com/v1/artists/2FgHPfRprDaylrSRVf1UlN',
#    'id': '2FgHPfRprDaylrSRVf1UlN',
#    'name': 'Thaman S',
#    'type': 'artist',
#    'uri': 'spotify:artist:2FgHPfRprDaylrSRVf1UlN'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '3lnOgTbiGMIvcZhvqBkHDa'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Ala Vaikunthapurramuloo'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2020-01-06'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 6

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/3lnOgTbiGMIvcZhvqBkHDa'

# %%
data['items'][0]['track']['album']['release_date_precision']
# Out:
# 'day'

# %%
data['items'][0]['track']['album']['uri']
# Out:
# 'spotify:album:3lnOgTbiGMIvcZhvqBkHDa'

# %% [markdown]
# # Album data

# %%
album_list=[]
for row in data['items']:

       album_id = row['track']['album']['id']
      
       album_name = row['track']['album']['name']
        
       album_release_date = row['track']['album']['release_date']
       
       album_total_tracks = row['track']['album']['total_tracks']
 
       album_url = row['track']['album']['external_urls']['spotify']
       album_release_date_precision=row['track']['album']['release_date_precision']        

       album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                            'total_tracks':album_total_tracks,'url':album_url,'release_date_precision':album_release_date_precision}
        
       album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '3lnOgTbiGMIvcZhvqBkHDa',
#   'name': 'Ala Vaikunthapurramuloo',
#   'release_date': '2020-01-06',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/3lnOgTbiGMIvcZhvqBkHDa',
#   'release_date_precision': 'day'},
#  {'album_id': '5yaWNdlJB8FoxwbngILePz',
#   'name': 'Padi Padi Leche Manasu',
#   'release_date': '2018-12-10',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/5yaWNdlJB8FoxwbngILePz',
#   'release_date_precision': 'day'},
#  {'album_id': '3JdE4IkqObXwTWzYKieCUv',
#   'name': 'Gang Leader (Original Motion Picture Soundtrack)',
#   'release_date': '2019-09-05',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/3JdE4IkqObXwTWzYKieCUv',
#   'release_date_precision': 'day'},
#  {'album_id': '3vzddHOuT5R28vKakxD0qJ',
#   'name': 'RX 100 (Original Motion Picture Soundtrack)',
#   'release_date': '2018-06-29',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/3vzddHOuT5R28vKakxD0qJ',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df['release_date']
# Out:
# 0     2020-01-06
# 1     2018-12-10
# 2     2019-09-05
# 3     2018-06-29
# 4           0000
#          ...
# 95    2014-12-03
# 96    2021-03-07
# 97    2021-01-31
# 98    2021-02-28
# 99    2021-03-07
# Name: release_date, Length: 100, dtype: object

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   album_id                100 non-null    object
#  1   name                    100 non-null    object
#  2   release_date            100 non-null    object
#  3   total_tracks            100 non-null    int64
#  4   url                     100 non-null    object
#  5   release_date_precision  100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
#drop duplicate values
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
df=album_df.drop(album_df[album_df['release_date']=='0000'].index)

# %%
df['release_date']
# Out:
# 0     2020-01-06
# 1     2018-12-10
# 2     2019-09-05
# 3     2018-06-29
# 5     2018-08-20
#          ...
# 92    2014-12-03
# 96    2021-03-07
# 97    2021-01-31
# 98    2021-02-28
# 99    2021-03-07
# Name: release_date, Length: 83, dtype: object

# %%
album_df=df.drop(df[df['release_date']=='2018'].index)

# %%
album_df['release_date']
# Out:
# 0     2020-01-06
# 1     2018-12-10
# 2     2019-09-05
# 3     2018-06-29
# 5     2018-08-20
#          ...
# 92    2014-12-03
# 96    2021-03-07
# 97    2021-01-31
# 98    2021-02-28
# 99    2021-03-07
# Name: release_date, Length: 82, dtype: object

# %%
pd.set_option('display.max_rows',250)

# %%
# cahnging the data type of release date:
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 82 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   album_id                82 non-null     object
#  1   name                    82 non-null     object
#  2   release_date            82 non-null     datetime64[ns]
#  3   total_tracks            82 non-null     int64
#  4   url                     82 non-null     object
#  5   release_date_precision  82 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 4.5+ KB

# %%
album_df['release_date_precision']
# Out:
# 0     day
# 1     day
# 2     day
# 3     day
# 5     day
# 6     day
# 7     day
# 8     day
# 9     day
# 10    day
# 11    day
# 12    day
# 13    day
# 14    day
# 15    day
# 16    day
# 17    day
# 18    day
# 19    day
# 20    day
# 21    day
# 22    day
# 23    day
# 24    day
# 25    day
# 26    day
# 27    day
# 28    day
# 29    day
# 30    day
# 31    day
# 32    day
# 33    day
# 34    day
# 35    day
# 36    day
# 37    day
# 38    day
# 39    day
# 41    day
# 44    day
# 46    day
# 47    day
# 48    day
# 49    day
# 50    day
# 51    day
# 52    day
# 53    day
# 54    day
# 55    day
# 57    day
# 58    day
# 59    day
# 60    day
# 61    day
# 62    day
# 63    day
# 64    day
# 65    day
# 66    day
# 67    day
# 68    day
# 69    day
# 70    day
# 71    day
# 72    day
# 73    day
# 77    day
# 78    day
# 79    day
# 80    day
# 81    day
# 82    day
# 84    day
# 85    day
# 91    day
# 92    day
# 96    day
# 97    day
# 98    day
# 99    day
# ...

# %% [markdown]
# # Artist data

# %%
data['items'][1]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IKVDbCSBTxBeAsMKjAuTs'},
#   'href': 'https://api.spotify.com/v1/artists/4IKVDbCSBTxBeAsMKjAuTs',
#   'id': '4IKVDbCSBTxBeAsMKjAuTs',
#   'name': 'Armaan Malik',
#   'type': 'artist',
#   'uri': 'spotify:artist:4IKVDbCSBTxBeAsMKjAuTs'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6KjiNHnbm1CNrIN0z7wJtO'},
#   'href': 'https://api.spotify.com/v1/artists/6KjiNHnbm1CNrIN0z7wJtO',
#   'id': '6KjiNHnbm1CNrIN0z7wJtO',
#   'name': 'Sinduri Vishal',
#   'type': 'artist',
#   'uri': 'spotify:artist:6KjiNHnbm1CNrIN0z7wJtO'}]

# %%
data['items'][1]['track']['artists'][0]['id']
# Out:
# '4IKVDbCSBTxBeAsMKjAuTs'

# %%
data['items'][1]['track']['artists'][0]['name']
# Out:
# 'Armaan Malik'

# %%
data['items'][1]['track']['artists'][0]['href']
# Out:
# 'https://api.spotify.com/v1/artists/4IKVDbCSBTxBeAsMKjAuTs'

# %%
data['items'][1]['track']['artists'][0]['type']
# Out:
# 'artist'

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href'],
                               'type':artist['type']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '7qjJw7ZM2ekDSahLXPjIlN',
#   'artist_name': 'Sid Sriram',
#   'external_url': 'https://api.spotify.com/v1/artists/7qjJw7ZM2ekDSahLXPjIlN',
#   'type': 'artist'},
#  {'artist_id': '4IKVDbCSBTxBeAsMKjAuTs',
#   'artist_name': 'Armaan Malik',
#   'external_url': 'https://api.spotify.com/v1/artists/4IKVDbCSBTxBeAsMKjAuTs',
#   'type': 'artist'},
#  {'artist_id': '6KjiNHnbm1CNrIN0z7wJtO',
#   'artist_name': 'Sinduri Vishal',
#   'external_url': 'https://api.spotify.com/v1/artists/6KjiNHnbm1CNrIN0z7wJtO',
#   'type': 'artist'},
#  {'artist_id': '4zCH9qm4R2DADamUHMCa6O',
#   'artist_name': 'Anirudh Ravichander',
#   'external_url': 'https://api.spotify.com/v1/artists/4zCH9qm4R2DADamUHMCa6O',
#   'type': 'artist'},
#  {'artist_id': '29cBzYwqCZF4fjCisS8UvU',
#   'artist_name': 'Inno Genga',
#   'external_url': 'https://api.spotify.com/v1/artists/29cBzYwqCZF4fjCisS8UvU',
#   'type': 'artist'},
#  {'artist_id': '6LWyVEIBnx7MoRBhQxu9om',
#   'artist_name': 'Anurag Kulkarni',
# ...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id          artist_name
# 0  7qjJw7ZM2ekDSahLXPjIlN           Sid Sriram  \
# 1  4IKVDbCSBTxBeAsMKjAuTs         Armaan Malik
# 2  6KjiNHnbm1CNrIN0z7wJtO       Sinduri Vishal
# 3  4zCH9qm4R2DADamUHMCa6O  Anirudh Ravichander
# 4  29cBzYwqCZF4fjCisS8UvU           Inno Genga
#
#                                         external_url    type
# 0  https://api.spotify.com/v1/artists/7qjJw7ZM2ek...  artist
# 1  https://api.spotify.com/v1/artists/4IKVDbCSBTx...  artist
# 2  https://api.spotify.com/v1/artists/6KjiNHnbm1C...  artist
# 3  https://api.spotify.com/v1/artists/4zCH9qm4R2D...  artist
# 4  https://api.spotify.com/v1/artists/29cBzYwqCZF...  artist

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109 entries, 0 to 185
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     109 non-null    object
#  1   artist_name   109 non-null    object
#  2   external_url  109 non-null    object
#  3   type          109 non-null    object
# dtypes: object(4)
# memory usage: 4.3+ KB

# %% [markdown]
# # song data

# %%
data['items'][0]['track']['name']
# Out:
# 'Samajavaragamana'

# %%
data['items'][0]['track']['popularity']
# Out:
# 55

# %%
data['items'][4]['track']['id']
# Out:
# '1YA5XoTcKyrpQ6cW6XsAfB'

# %%
data['items'][0]['track']['duration_ms']
# Out:
# 219818

# %%
data['items'][0]['track']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/track/0h5wFi2R8a9ReSIDbXzZgy'

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '0h5wFi2R8a9ReSIDbXzZgy',
#   'song_name': 'Samajavaragamana',
#   'duration_ms': 219818,
#   'url': 'https://open.spotify.com/track/0h5wFi2R8a9ReSIDbXzZgy',
#   'popularity': 55,
#   'song_added': '2020-11-15T16:50:01Z',
#   'album_id': '3lnOgTbiGMIvcZhvqBkHDa',
#   'artist_id': '2FgHPfRprDaylrSRVf1UlN'},
#  {'song_id': '7tXaDnRF8OVbcecl0KurVn',
#   'song_name': 'Padi Padi Leche',
#   'duration_ms': 203777,
#   'url': 'https://open.spotify.com/track/7tXaDnRF8OVbcecl0KurVn',
#   'popularity': 61,
#   'song_added': '2020-11-15T16:50:22Z',
#   'album_id': '5yaWNdlJB8FoxwbngILePz',
#   'artist_id': '0rL4uL3xfYOt2p7NHhS8qr'},
#  {'song_id': '7mNQwVYgoB3mtjkjCKsbXM',
#   'song_name': 'Hoyna Hoyna',
#   'duration_ms': 271937,
#   'url': 'https://open.spotify.com/track/7mNQwVYgoB3mtjkjCKsbXM',
#   'popularity': 65,
#   'song_added': '2020-11-15T16:55:12Z',
#   'album_id': '3JdE4IkqObXwTWzYKieCUv',
#   'artist_id': '4zCH9qm4R2DADamUHMCa6O'},
# ...

# %%
#song dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id         song_name  duration_ms
# 0  0h5wFi2R8a9ReSIDbXzZgy  Samajavaragamana       219818  \
# 1  7tXaDnRF8OVbcecl0KurVn   Padi Padi Leche       203777
# 2  7mNQwVYgoB3mtjkjCKsbXM       Hoyna Hoyna       271937
# 3  47hP2BJPCOMyYKT5WQ9evZ        Pillaa Raa       237580
# 4  1YA5XoTcKyrpQ6cW6XsAfB                              0
#
#                                                  url  popularity
# 0  https://open.spotify.com/track/0h5wFi2R8a9ReSI...          55  \
# 1  https://open.spotify.com/track/7tXaDnRF8OVbcec...          61
# 2  https://open.spotify.com/track/7mNQwVYgoB3mtjk...          65
# 3  https://open.spotify.com/track/47hP2BJPCOMyYKT...           0
# 4  https://open.spotify.com/track/1YA5XoTcKyrpQ6c...           0
#
#              song_added                album_id               artist_id
# 0  2020-11-15T16:50:01Z  3lnOgTbiGMIvcZhvqBkHDa  2FgHPfRprDaylrSRVf1UlN
# 1  2020-11-15T16:50:22Z  5yaWNdlJB8FoxwbngILePz  0rL4uL3xfYOt2p7NHhS8qr
# ...

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])

# %%
song_df.head()
# Out:
#                   song_id         song_name  duration_ms
# 0  0h5wFi2R8a9ReSIDbXzZgy  Samajavaragamana       219818  \
# 1  7tXaDnRF8OVbcecl0KurVn   Padi Padi Leche       203777
# 2  7mNQwVYgoB3mtjkjCKsbXM       Hoyna Hoyna       271937
# 3  47hP2BJPCOMyYKT5WQ9evZ        Pillaa Raa       237580
# 4  1YA5XoTcKyrpQ6cW6XsAfB                              0
#
#                                                  url  popularity
# 0  https://open.spotify.com/track/0h5wFi2R8a9ReSI...          55  \
# 1  https://open.spotify.com/track/7tXaDnRF8OVbcec...          61
# 2  https://open.spotify.com/track/7mNQwVYgoB3mtjk...          65
# 3  https://open.spotify.com/track/47hP2BJPCOMyYKT...           0
# 4  https://open.spotify.com/track/1YA5XoTcKyrpQ6c...           0
#
#              song_added                album_id               artist_id
# 0  2020-11-15T16:50:01Z  3lnOgTbiGMIvcZhvqBkHDa  2FgHPfRprDaylrSRVf1UlN
# 1  2020-11-15T16:50:22Z  5yaWNdlJB8FoxwbngILePz  0rL4uL3xfYOt2p7NHhS8qr
# ...

# %%
song_df=song_df.drop(song_df[song_df['song_name']==''].index)

# %%
song_df['song_added']
# Out:
# 0     2020-11-15T16:50:01Z
# 1     2020-11-15T16:50:22Z
# 2     2020-11-15T16:55:12Z
# 3     2020-11-15T16:55:26Z
# 5     2022-08-06T15:01:36Z
# 6     2020-11-15T16:55:40Z
# 7     2020-11-15T17:00:21Z
# 8     2022-08-06T15:01:10Z
# 9     2022-08-06T15:01:14Z
# 10    2022-08-06T15:01:18Z
# 11    2022-08-06T15:01:22Z
# 12    2022-08-06T15:01:25Z
# 13    2022-08-06T15:01:49Z
# 14    2022-08-06T15:01:52Z
# 15    2020-11-15T17:00:45Z
# 16    2020-11-15T17:00:59Z
# 17    2020-11-15T17:01:18Z
# 18    2020-11-15T17:01:29Z
# 19    2020-11-15T17:01:51Z
# 20    2020-11-26T14:08:08Z
# 21    2020-11-26T14:09:53Z
# 22    2020-11-26T14:12:59Z
# 23    2020-11-26T14:13:48Z
# 24    2020-11-26T14:16:25Z
# 25    2020-11-26T14:18:32Z
# 26    2020-11-26T14:19:31Z
# 27    2020-11-26T14:21:31Z
# 28    2020-11-26T14:22:47Z
# 29    2020-11-26T14:23:49Z
# 30    2020-11-26T14:33:01Z
# 31    2020-11-26T14:34:31Z
# 32    2020-11-26T14:35:17Z
# 33    2020-11-26T14:40:39Z
# 34    2020-11-26T14:41:55Z
# ...

# %%
song_df['song_added]'=pd.to_datetime()

# %%
song_df=df
song_df.head()
# Out:
#                   song_id         song_name  duration_ms
# 0  0h5wFi2R8a9ReSIDbXzZgy  Samajavaragamana       219818  \
# 1  7tXaDnRF8OVbcecl0KurVn   Padi Padi Leche       203777
# 2  7mNQwVYgoB3mtjkjCKsbXM       Hoyna Hoyna       271937
# 3  47hP2BJPCOMyYKT5WQ9evZ        Pillaa Raa       237580
# 5  1lrgvbZzsjatMee0Uk8o0P       Asha Pasham       260000
#
#                                                  url  popularity
# 0  https://open.spotify.com/track/0h5wFi2R8a9ReSI...          55  \
# 1  https://open.spotify.com/track/7tXaDnRF8OVbcec...          61
# 2  https://open.spotify.com/track/7mNQwVYgoB3mtjk...          65
# 3  https://open.spotify.com/track/47hP2BJPCOMyYKT...           0
# 5  https://open.spotify.com/track/1lrgvbZzsjatMee...          59
#
#              song_added                album_id               artist_id
# 0  2020-11-15T16:50:01Z  3lnOgTbiGMIvcZhvqBkHDa  2FgHPfRprDaylrSRVf1UlN
# 1  2020-11-15T16:50:22Z  5yaWNdlJB8FoxwbngILePz  0rL4uL3xfYOt2p7NHhS8qr
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      91 non-null     object
#  1   song_name    91 non-null     object
#  2   duration_ms  91 non-null     int64
#  3   url          91 non-null     object
#  4   popularity   91 non-null     int64
#  5   song_added   91 non-null     object
#  6   album_id     91 non-null     object
#  7   artist_id    91 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      91 non-null     object
#  1   song_name    91 non-null     object
#  2   duration_ms  91 non-null     int64
#  3   url          91 non-null     object
#  4   popularity   91 non-null     int64
#  5   song_added   91 non-null     datetime64[ns, UTC]
#  6   album_id     91 non-null     object
#  7   artist_id    91 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
